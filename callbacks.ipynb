# %% [markdown]
# # Wine Quality

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("winequalityN.csv")
df.sample(5)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1969  white            6.3              0.41         0.30            3.20
# 2489  white            6.1              0.28         0.24           19.95
# 5290    red            9.5              0.37         0.52            2.00
# 3017  white            5.9              0.34         0.30            3.80
# 699   white            7.4              0.31         0.48           14.20
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1969      0.030                 49.0                 164.0  0.99270  3.53
# 2489      0.074                 32.0                 174.0  0.99922  3.19
# 5290      0.082                  6.0                  26.0  0.99800  3.18
# 3017      0.035                 57.0                 135.0  0.99016  3.09
# 699       0.042                 62.0                 204.0  0.99830  3.06
#
#       sulphates  alcohol  quality
# 1969       0.79     11.7        7
# 2489       0.44      9.3        6
# 5290       0.51      9.5        5
# 3017       0.34     12.0        6
# 699        0.59      9.4        5

# %%
# wine type
df["wine_type"] = [1 if wine_type == "white" else 0 for wine_type in df["type"]]
df.sample(5)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 5905    red            9.1              0.30         0.34            2.00
# 5580    red            8.5              0.46         0.31            2.25
# 1279  white            6.6              0.27         0.30            1.90
# 176   white            7.2              0.32         0.47            5.10
# 5366    red           11.4              0.36         0.69            2.10
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 5905      0.064                 12.0                  25.0  0.99516  3.26
# 5580      0.078                 32.0                  58.0  0.99800  3.33
# 1279      0.025                 14.0                 153.0  0.99280  3.29
# 176       0.044                 19.0                  65.0  0.99100  3.03
# 5366      0.090                  6.0                  21.0  1.00000  3.17
#
#       sulphates  alcohol  quality  wine_type
# 5905       0.84     11.7        7          0
# 5580       0.54      9.8        5          0
# 1279       0.62     10.5        6          1
# 176        0.41     12.6        4          1
# 5366       0.62      9.2        6          0

# %%
# wine quality
df["wine_quality"] = [1 if quality > 5 else 0 for quality in df["quality"]]
df.sample(5)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1773  white            7.8             0.390         0.26             9.9
# 5661    red            9.3             0.655         0.26             2.0
# 6019    red            6.6             0.500         0.00             1.8
# 6223    red            6.7             0.460         0.24             1.7
# 5362    red           11.5             0.315         0.54             2.1
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1773      0.059                 33.0                 181.0  0.99550  3.04
# 5661      0.096                  5.0                  35.0  0.99738  3.25
# 6019      0.062                 21.0                  28.0  0.99352  3.44
# 6223      0.077                 18.0                  34.0  0.99480  3.39
# 5362      0.084                  5.0                  15.0  0.99870  2.98
#
#       sulphates  alcohol  quality  wine_type  wine_quality
# 1773       0.42     10.9        6          1             1
# 5661       0.42      9.6        5          0             0
# 6019       0.55     12.3        6          0             1
# 6223       0.60     10.6        6          0             1
# 5362       0.70      9.2        6          0             1

# %%
df.drop(columns=["type", "quality"], inplace=True)
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6411            6.4             0.560         0.15             1.8      0.078
# 5742            9.9             0.250         0.46             1.7      0.062
# 3773            5.0             0.610         0.12             1.3      0.009
# 1491            7.5             0.200         0.49             1.3      0.031
# 5763            7.2             0.635         0.07             2.6      0.077
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6411                 17.0                  65.0  0.99294  3.33       0.60
# 5742                 26.0                  42.0  0.99590  3.18       0.83
# 3773                 65.0                 100.0  0.98740  3.26       0.37
# 1491                  8.0                  97.0  0.99180  3.06       0.62
# 5763                 16.0                  86.0  0.99748  3.51       0.54
#
#       alcohol  wine_type  wine_quality
# 6411     10.5          0             1
# 5742     10.6          0             1
# 3773     13.5          1             0
# 1491     11.1          1             0
# 5763      9.7          0             0

# %%
X = df.drop(columns=["wine_quality"])
y = df["wine_quality"]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y, test_size = 0.2, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5197, 12)
# (1300, 12)
# (5197,)
# (1300,)

# %%
np.bincount(y_train)
# Out:
# array([1916, 3281])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

tf.random.set_seed(42) #This is crucial for ensuring reproducibility in your experiments.

# %% [markdown]
# ## Callbacks

# %% [markdown]
# #### Model Checkpoint - saves the model on a current epoch if the validation metric improved from the previous epoch

# %%
cb_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath = "checkpoints/model-{epoch:02d}-{val_accuracy:.2f}.hdf5",
    monitor = "val_accuracy",
    mode="max",
    save_best_only = True,
    verbose = 1
)

# %% [markdown]
# #### ReduceLROnPlateau - reduces learning rate when there's no progress in training

# %%
reducelr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor = "val_loss",
    mode = "min",
    factor = 0.1,
    patience = 10,
    min_lr = 0.00001,
    verbose = 1
)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor = "val_accuracy",
    min_delta = 0.001,
    patience = 10,
    verbose = 1,
    mode = "max"
)

# %%
csvlog = tf.keras.callbacks.CSVLogger(
    filename = "trianing_log.csv",
    separator = ",",
    append = True
)

# %% [markdown]
# ## Model Training

# %%
model = Sequential([
    Dense(units=32, activation="relu"),
    Dense(units=16, activation="relu"),
    Dense(units=8, activation="relu"),
    Dense(units=1, activation="sigmoid")]
)

# %%
loss = tf.keras.losses.BinaryCrossentropy()
opt = tf.keras.optimizers.Adam()
bin_acc = tf.keras.metrics.BinaryAccuracy(name="accuracy")
acc = tf.keras.metrics.Accuracy(name="normal acc")
model.compile(
    loss=loss,
    optimizer=opt,
    metrics=[bin_acc, acc]
)

# %%
model.fit(
    X_train,
    y_train,
    epochs = 300,
    validation_data = (X_test, y_test),
    callbacks = [cb_checkpoint, reducelr, earlystop, csvlog]
)
# Out:
# Epoch 1/300
# 153/163 [===========================>..] - ETA: 0s - loss: nan - accuracy: 0.3703 - normal acc: 0.0000e+00
# Epoch 1: val_accuracy did not improve from 0.36000
# 163/163 [==============================] - 2s 4ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 0.0010
# Epoch 2/300
# 143/163 [=========================>....] - ETA: 0s - loss: nan - accuracy: 0.3700 - normal acc: 0.0000e+00
# Epoch 2: val_accuracy did not improve from 0.36000
# 163/163 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 0.0010
# Epoch 3/300
# 141/163 [========================>.....] - ETA: 0s - loss: nan - accuracy: 0.3690 - normal acc: 0.0000e+00
# Epoch 3: val_accuracy did not improve from 0.36000
# 163/163 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 0.0010
# Epoch 4/300
# 139/163 [========================>.....] - ETA: 0s - loss: nan - accuracy: 0.3656 - normal acc: 0.0000e+00
# Epoch 4: val_accuracy did not improve from 0.36000
# 163/163 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 0.0010
# Epoch 5/300
# 154/163 [===========================>..] - ETA: 0s - loss: nan - accuracy: 0.3695 - normal acc: 0.0000e+00
# Epoch 5: val_accuracy did not improve from 0.36000
# 163/163 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 0.0010
# Epoch 6/300
# 152/163 [==========================>...] - ETA: 0s - loss: nan - accuracy: 0.3672 - normal acc: 0.0000e+00
# Epoch 6: val_accuracy did not improve from 0.36000
# 163/163 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 0.0010
# Epoch 7/300
# 144/163 [=========================>....] - ETA: 0s - loss: nan - accuracy: 0.3709 - normal acc: 0.0000e+00
# Epoch 7: val_accuracy did not improve from 0.36000
# 163/163 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 0.0010
# Epoch 8/300
# 148/163 [==========================>...] - ETA: 0s - loss: nan - accuracy: 0.3685 - normal acc: 0.0000e+00
# Epoch 8: val_accuracy did not improve from 0.36000
# 163/163 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 0.0010
# Epoch 9/300
# 147/163 [==========================>...] - ETA: 0s - loss: nan - accuracy: 0.3654 - normal acc: 0.0000e+00
# Epoch 9: val_accuracy did not improve from 0.36000
# 163/163 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 0.0010
# Epoch 10/300
# 161/163 [============================>.] - ETA: 0s - loss: nan - accuracy: 0.3684 - normal acc: 0.0000e+00
# Epoch 10: val_accuracy did not improve from 0.36000
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 163/163 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 0.0010
# Epoch 11/300
# 149/163 [==========================>...] - ETA: 0s - loss: nan - accuracy: 0.3708 - normal acc: 0.0000e+00
# Epoch 11: val_accuracy did not improve from 0.36000
# 163/163 [==============================] - 1s 4ms/step - loss: nan - accuracy: 0.3687 - normal acc: 0.0000e+00 - val_loss: nan - val_accuracy: 0.3600 - val_normal acc: 0.0000e+00 - lr: 1.0000e-04
# Epoch 11: early stopping

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 32)                416
#
#  dense_9 (Dense)             (None, 16)                528
#
#  dense_10 (Dense)            (None, 8)                 136
#
#  dense_11 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 1089 (4.25 KB)
# Trainable params: 1089 (4.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
